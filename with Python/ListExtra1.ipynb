# %%
#reference : https://qiita.com/shinji_komine/items/460ca7a953131d749203
#reference : https://www.sairablog.com/article/pca-visualization-principle-component-analysis.html

# %%
from sklearn.datasets import fetch_openml
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

mnist = fetch_openml('mnist_784')
#標準化
x = mnist.data.to_numpy()
scaler = StandardScaler()
scaler.fit(x)
x = scaler.transform(x)

# %%
number = 2

plt.figure(figsize=(15,15))
for i, j in zip(range(0, 784, 30), range(20)):
    pca = PCA(n_components = (i + 1)) #復元の変換をちゃんと読み解けばPCAの呼び出しは一回で済むと思います．
    data = pca.fit_transform(x)
    data = pca.inverse_transform(data)
    plt.subplot(5,5,j + 1)
    plt.imshow(data[number].reshape(28,28), cmap='gray')
